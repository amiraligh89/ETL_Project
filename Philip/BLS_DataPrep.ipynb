# %%
# Dependencies
import pandas as pd
import os
import csv
import glob

# %%
path = r'/Users/philipnunoo/ETL_Project/Philip/Data/' # use your path
all_files = glob.glob(path + "*.xlsx")

#print(all_files)

li = []

for filename in all_files:
   print(filename)
   print("------")
   df = pd.read_excel(filename, skiprows=12)
   df['Filename'] = filename 
   li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
frame
# Out:
# /Users/philipnunoo/ETL_Project/Philip/Data/446_Health_Personal_Care_Stores.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/447_Gasoline_Stations.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/448_Clothing_Clothing_Accessories_Stores.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/445_Food_Beverage_Stores.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/451_SportingGoods_Hobby_Book_Music_Stores.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/442_Furniture_Home_Furnishings_Stores.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/441_MotorVehicle_PartsDealers.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/444_BuildingMaterial_GardenSupplies.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/454_Nonstore_Retailers.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/443_Electronics_Appliance_Stores.xlsx
# ------
# /Users/philipnunoo/ETL_Project/Philip/Data/453_Miscellaneous_Store_Retailers.xlsx
# ...

# %%
frame['Filename']
print(os.path.basename(frame['Filename']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-9be92c89efd8> in <module>
#       1 frame['Filename']
# ----> 2 print(os.path.basename(frame['Filename']))
#
# /anaconda3/envs/PythonData/lib/python3.7/posixpath.py in basename(p)
#     144 def basename(p):
#     145     """Returns the final component of a pathname"""
# --> 146     p = os.fspath(p)
#     147     sep = _get_sep(p)
#     148     i = p.rfind(sep) + 1
#
# TypeError: expected str, bytes or os.PathLike object, not Series

# %%
# Store filepath in a variable
file_441 = "441_MotorVehicle_PartsDealers.xlsx"

# %%
#Read in File starting from 13th row to eliminate extra headings and merged columns
file_441_df = pd.read_excel(file_441, skiprows=12)
file_441_df
# Out:
#     Year     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0   2009  1368.9  1361.9  1354.0  1355.1  1355.7  1358.7  1357.6  1357.8
# 1   2010  1301.6  1300.1  1309.4  1333.3  1343.1  1348.0  1348.0  1356.6
# 2   2011  1344.5  1352.8  1366.1  1385.6  1393.6  1404.3  1411.7  1412.9
# 3   2012  1384.4  1394.4  1404.0  1421.1  1426.4  1440.0  1436.5  1441.7
# 4   2013  1428.5  1432.2  1446.2  1459.9  1474.1  1486.5  1496.0  1498.9
# 5   2014  1490.0  1499.4  1511.2  1532.5  1546.2  1565.4  1567.3  1571.4
# 6   2015  1557.0  1566.7  1581.8  1593.4  1610.5  1619.5  1629.4  1629.2
# 7   2016  1615.1  1621.3  1635.2  1641.9  1651.6  1658.8  1661.7  1659.5
# 8   2017  1642.0  1646.1  1654.7  1659.9  1665.1  1674.6  1676.9  1672.1
# 9   2018  1647.8  1658.5  1662.3  1670.7  1678.6  1688.5  1695.0  1690.6
# 10  2019  1672.9  1677.0  1689.9  1699.9  1708.7     NaN     NaN     NaN
#
#        Sep     Oct     Nov     Dec
# 0   1348.3  1343.9  1329.1  1323.3
# ...

# %%
#file_441_df.unstack(10)

file_441_df.melt(id_vars=["Year","NAICS CODE"],var_name="Month",value_name="Value")
# Out:
#      Year Month   Value
# 0    2009   Jan  1368.9
# 1    2010   Jan  1301.6
# 2    2011   Jan  1344.5
# 3    2012   Jan  1384.4
# 4    2013   Jan  1428.5
# 5    2014   Jan  1490.0
# 6    2015   Jan  1557.0
# 7    2016   Jan  1615.1
# 8    2017   Jan  1642.0
# 9    2018   Jan  1647.8
# 10   2019   Jan  1672.9
# 11   2009   Feb  1361.9
# 12   2010   Feb  1300.1
# 13   2011   Feb  1352.8
# 14   2012   Feb  1394.4
# 15   2013   Feb  1432.2
# 16   2014   Feb  1499.4
# 17   2015   Feb  1566.7
# 18   2016   Feb  1621.3
# 19   2017   Feb  1646.1
# 20   2018   Feb  1658.5
# 21   2019   Feb  1677.0
# 22   2009   Mar  1354.0
# 23   2010   Mar  1309.4
# 24   2011   Mar  1366.1
# 25   2012   Mar  1404.0
# 26   2013   Mar  1446.2
# 27   2014   Mar  1511.2
# 28   2015   Mar  1581.8
# 29   2016   Mar  1635.2
# ..    ...   ...     ...
# 102  2012   Oct  1446.1
# 103  2013   Oct  1498.3
# 104  2014   Oct  1566.3
# 105  2015   Oct  1622.7
# 106  2016   Oct  1655.1
# 107  2017   Oct  1667.7
# ...

# %%
#Transpose data file
file_441_TR_df = file_441_df.T

#file_441_TR_df['NAICS Code']='441'
file_441_TR_df
# Out:
#            0       1       2       3       4       5       6       7       8  \
# Year  2009.0  2010.0  2011.0  2012.0  2013.0  2014.0  2015.0  2016.0  2017.0
# Jan   1368.9  1301.6  1344.5  1384.4  1428.5  1490.0  1557.0  1615.1  1642.0
# Feb   1361.9  1300.1  1352.8  1394.4  1432.2  1499.4  1566.7  1621.3  1646.1
# Mar   1354.0  1309.4  1366.1  1404.0  1446.2  1511.2  1581.8  1635.2  1654.7
# Apr   1355.1  1333.3  1385.6  1421.1  1459.9  1532.5  1593.4  1641.9  1659.9
# May   1355.7  1343.1  1393.6  1426.4  1474.1  1546.2  1610.5  1651.6  1665.1
# Jun   1358.7  1348.0  1404.3  1440.0  1486.5  1565.4  1619.5  1658.8  1674.6
# Jul   1357.6  1348.0  1411.7  1436.5  1496.0  1567.3  1629.4  1661.7  1676.9
# Aug   1357.8  1356.6  1412.9  1441.7  1498.9  1571.4  1629.2  1659.5  1672.1
# Sep   1348.3  1356.6  1412.5  1442.5  1502.2  1570.5  1624.4  1657.1  1664.3
# Oct   1343.9  1358.2  1410.9  1446.1  1498.3  1566.3  1622.7  1655.1  1667.7
# ...

# %%
#file_441_df.reset_index()
#file_441_TR_df

file_441_df.pivot(index="Year", columns='Jan')
# Out:
#          Feb                                                                  \
# Jan   1301.6  1344.5  1368.9  1384.4  1428.5  1490.0  1557.0  1615.1  1642.0
# Year
# 2009     NaN     NaN  1361.9     NaN     NaN     NaN     NaN     NaN     NaN
# 2010  1300.1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2011     NaN  1352.8     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012     NaN     NaN     NaN  1394.4     NaN     NaN     NaN     NaN     NaN
# 2013     NaN     NaN     NaN     NaN  1432.2     NaN     NaN     NaN     NaN
# 2014     NaN     NaN     NaN     NaN     NaN  1499.4     NaN     NaN     NaN
# 2015     NaN     NaN     NaN     NaN     NaN     NaN  1566.7     NaN     NaN
# 2016     NaN     NaN     NaN     NaN     NaN     NaN     NaN  1621.3     NaN
# 2017     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  1646.1
# 2018     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
file_441_TR_df.unstack()

#file_441_TR_df.reset_index()
#file_441_TR_df

#file_441_TR_df.pivot(index="Year")
# Out:
# 0           Year      2009
#             Jan     1368.9
#             Feb     1361.9
#             Mar       1354
#             Apr     1355.1
#             May     1355.7
#             Jun     1358.7
#             Jul     1357.6
#             Aug     1357.8
#             Sep     1348.3
#             Oct     1343.9
#             Nov     1329.1
#             Dec     1323.3
# 1           Year      2010
#             Jan     1301.6
#             Feb     1300.1
#             Mar     1309.4
#             Apr     1333.3
#             May     1343.1
#             Jun       1348
#             Jul       1348
#             Aug     1356.6
#             Sep     1356.6
#             Oct     1358.2
#             Nov     1359.8
#             Dec     1357.6
# 2           Year      2011
#             Jan     1344.5
#             Feb     1352.8
#             Mar     1366.1
#                      ...
# 9           Sep     1688.9
#             Oct     1689.6
#             Nov     1681.8
# ...

# %%
#Put Data into a DataFrame
file_441_df=pd.DataFrame(file_441_raw)

file_441_df
#file_441_df.dropna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8c606d2679c4> in <module>
#       1 #Put Data into a DataFrame
# ----> 2 file_441_df=pd.DataFrame(file_441_raw)
#       3
#       4 file_441_df
#       5 #file_441_df.dropna()
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# --> 468                 raise ValueError('DataFrame constructor not properly called!')
#     469
#     470         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
# Export file as a CSV, without the Pandas index, but with the header
file_441_df.to_csv("Output/file_441.csv", index=False, header=True)
